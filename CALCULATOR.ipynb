# %%
def calculator():
    print("Welcome to the simple calculator!")

    while True:
        print("\nPlease choose an operation:")
        print("1. Addition (+)")
        print("2. Subtraction (-)")
        print("3. Multiplication (*)")
        print("4. Division (/)")
        print("Enter 'q' to quit.")

        operation = input("Enter the number corresponding to the operation: ")

        if operation == 'q':
            print("Thank you for using the calculator!!")
            break

        num1 = float(input("Enter the first number: "))
        num2 = float(input("Enter the second number: "))

        if operation == '1':
            result = num1 + num2
            operation_symbol = '+'
        elif operation == '2':
            result = num1 - num2
            operation_symbol = '-'
        elif operation == '3':
            result = num1 * num2
            operation_symbol = '*'
        elif operation == '4':
            if num2 == 0:
                print("Error: Division by zero is not allowed.")
                continue
            result = num1 / num2
            operation_symbol = '/'
        else:
            print("Invalid operation. Please choose a valid option.")
            continue

        print(f"The result of {num1} {operation_symbol} {num2} is: {result}")

calculator()
# Out:
# Welcome to the simple calculator!
#
# Please choose an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# Enter 'q' to quit.
# Enter the number corresponding to the operation: 1
# Enter the first number: 123
# Enter the second number: 456
# The result of 123.0 + 456.0 is: 579.0
#
# Please choose an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# Enter 'q' to quit.
# Enter the number corresponding to the operation: 2
# Enter the first number: 456
# Enter the second number: 123
# The result of 456.0 - 123.0 is: 333.0
#
# Please choose an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# Enter 'q' to quit.
# Enter the number corresponding to the operation: 2
# Enter the first number: 123
# Enter the second number: 456
# The result of 123.0 - 456.0 is: -333.0
#
# Please choose an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# Enter 'q' to quit.
# Enter the number corresponding to the operation: 3
# Enter the first number: 123
# Enter the second number: 456
# The result of 123.0 * 456.0 is: 56088.0
#
# Please choose an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# Enter 'q' to quit.
# Enter the number corresponding to the operation: 4
# Enter the first number: 456
# Enter the second number: 123
# The result of 456.0 / 123.0 is: 3.707317073170732
#
# Please choose an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# Enter 'q' to quit.
# Enter the number corresponding to the operation: 4
# Enter the first number: 123
# Enter the second number: 456
# The result of 123.0 / 456.0 is: 0.26973684210526316
#
# Please choose an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# Enter 'q' to quit.
# Enter the number corresponding to the operation: q
# Thank you for using the calculator!!
